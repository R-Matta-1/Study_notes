# %% [markdown]
# ## i just go through questions,
# ---

# %% [markdown]
# # geometry
#
# ![Screenshot 2024-05-19 195513.png](<attachment:Screenshot 2024-05-19 195513.png>)
#
# well, the diameter and the diagonal are the same thing... so find the diagonal
#
# here remembering the $1/2/ {\sqrt 3 }$  and 30/60/90 triangle is cool but let's imagine you don't
#
# we can use reverse sin 1/2 to find the opposite angle and then cos *h  = a
#
# $$\cos(\sin^{-1}(\frac 12))2 = h \\ \cos(30 \degree)2x \\ \frac{\sqrt{3}}{2}2 x\\ \\\sqrt 3 x$$
#
# so now we have a 1x \ 2x \ $\sqrt 3 x$ triangle, but you should memorize that on this timed test. hopefully this helps
#
# if we can solve for x we can mult that by 2 then we have our area, like this
#
# - $\text{area} = w\times h$
# - $\text{area} = x\times x\sqrt 3$
# - $\text{area} = x^2\sqrt 3$
# - $\frac{1089\cancel {\sqrt 3}}{\cancel{\sqrt 3}} = x^2$
# - $\sqrt{1089}=x$
# - then x*2 = our awnser = 66

# %% [markdown]
# # those triangle questions
# next
